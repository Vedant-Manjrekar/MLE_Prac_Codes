# %% [markdown]
# # Flow of Data Representation

# %% [markdown]
# 1. Import Dataset
# 2. Segregate labels and features
# 3. Identify data types
# 4. Segregate Categorical and Numerical Features
# 5. Encode Categorical Variables (if needed)
# 6. Scale Numerical Features
# 7. Normalizing values
# 8. Handling date and time feaures
# 9. Feature Selection (Mutual Info classif)
# 10. Corelation Analysis
