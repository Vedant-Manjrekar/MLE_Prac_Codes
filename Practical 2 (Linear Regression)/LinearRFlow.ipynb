# %% [markdown]
# # Linear Regression Flow

# %% [markdown]
# - Load dataset
# - Inspect dataset
# - - 1. Check basic info
# - - 2. Check for missing values
# - - 3. Check for datatype consistency
# - - 4. Check for outliers `data.describe()`
# - - 5. Check data is upto data (date/timestamp checking)
# - - 6. Check for Bias
# - Separate features and labels
# - Split data into train and test
# - Train the model
# - Make Predictions
# - Plot line of regressionl
